# %%
# TODO: Switch using uv python environment to conda in order to use pygmo

# Requirements:
# - [ ] Electricy price timeseries data for a full year (Ce, units?)
# - [x] Ambient temperature, relative humidity and precipitation timeseries for a full year (Tamb, HR and pp, ºC, %, mm)
# - [ ] Define regenerated water max flow rate (qr_max, m3/h) - 1/3 of qwct max?
# - [ ] Load conditions (mass flow rate and temperature) for a full year (mv and Tv, kg/s and ºC)

# Implementation steps:
# - [ ] Model water availability in reservoir as a function of precipitations
# - [ ] Define a pygmo problem interface for the WCT problem: receeding-horizon optimization using some local or global?
# - [ ] Evaluate for a full day
